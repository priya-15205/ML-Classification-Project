# %%
import pandas as pd

df = pd.read_csv('loan_prediction.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c9b222d-36ff-410b-b393-02b11fd17250" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c9b222d-36ff-410b-b393-02b11fd17250">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# **Scaled Data**

# %%
from sklearn.preprocessing import StandardScaler

# Separate features and target
X = df_balanced.drop('Loan_Status', axis=1)
y = df_balanced['Loan_Status']

# Apply scaling
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("Scaling completed successfully")
# Out:
# Scaling completed successfully

# %% [markdown]
# **Scaled data into a Dataframe**

# %%
X_scaled = pd.DataFrame(
    X_scaled,
    columns=X.columns
)

X_scaled.head()
# Out:
#     Loan_ID    Gender   Married  Dependents  Education  Self_Employed  \
# 0 -1.762067  0.544488 -1.167966   -0.693806  -0.479917      -0.336833
# 1 -1.756287  0.544488  0.856189    0.368938  -0.479917      -0.336833
# 2 -1.750506  0.544488  0.856189   -0.693806  -0.479917       2.968830
# 3 -1.744725  0.544488  0.856189   -0.693806   2.083692      -0.336833
# 4 -1.738944  0.544488 -1.167966   -0.693806  -0.479917      -0.336833
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         0.111353          -0.585010   -0.214099          0.290476
# 1        -0.119446          -0.024970   -0.214099          0.290476
# 2        -0.408036          -0.585010   -0.986331          0.290476
# 3        -0.484058           0.290703   -0.313742          0.290476
# 4         0.138881          -0.585010   -0.052180          0.290476
#
#    Credit_History  Property_Area
# 0        0.559078       1.372037
# 1        0.559078      -1.218566
# ...

# %%
X_scaled.describe()
# Out:
#             Loan_ID        Gender       Married    Dependents     Education  \
# count  8.440000e+02  8.440000e+02  8.440000e+02  8.440000e+02  8.440000e+02
# mean  -3.367501e-17 -1.683751e-16 -1.010250e-16 -6.314065e-17  8.418753e-18
# std    1.000593e+00  1.000593e+00  1.000593e+00  1.000593e+00  1.000593e+00
# min   -1.762067e+00 -1.836588e+00 -1.167966e+00 -6.938056e-01 -4.799174e-01
# 25%   -8.501433e-01  5.444878e-01 -1.167966e+00 -6.938056e-01 -4.799174e-01
# 50%    3.972600e-03  5.444878e-01  8.561890e-01 -6.938056e-01 -4.799174e-01
# 75%    8.508625e-01  5.444878e-01  8.561890e-01  3.689383e-01 -4.799174e-01
# max    1.781574e+00  5.444878e-01  8.561890e-01  2.494426e+00  2.083692e+00
#
#        Self_Employed  ApplicantIncome  CoapplicantIncome    LoanAmount  \
# count   8.440000e+02     8.440000e+02       8.440000e+02  8.440000e+02
# mean   -4.209376e-17     6.314065e-17       3.577970e-17  2.630860e-17
# ...

# %% [markdown]
# **Observations**
#
# 1. Feature scaling was performed using StandardScaler.
# 2. The numerical features were standardized.
# 3. Scaling ensures that variables with larger values do not dominate variables with smaller values.
# 4. This preprocessing step can improve model performance and training efficiency.
